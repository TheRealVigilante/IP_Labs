# %%
from skimage import io,color
from skimage.filters import threshold_otsu,rank
from skimage.morphology import disk,skeletonize,closing,opening,erosion,dilation

# %% [markdown]
# # Task 1

# %%
Deku = io.imread('DekuImg.jpg', as_gray=True)
io.imshow(Deku)
io.show()
