# %% [markdown]
# ### AI-361-Lab-4

# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
def plot_comparison(original, processed, title):
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    ax = axes.ravel()

    # Display images using skimage's imshow
    io.imshow(original, ax=ax[0] , cmap = 'gray')
    ax[0].set_title("Original")

    io.imshow(processed, ax=ax[1], cmap = 'gray')
    ax[1].set_title(title)

    for a in ax:
        a.axis('off')

    io.show()

# %%
image1 = io.imread('image1.png')
image2 = io.imread('image2.png')
image3 = io.imread('image3.png')
plt.imshow(image1, cmap='gray')
plt.show()

# %%
from skimage.morphology import dilation, binary_dilation,isotropic_dilation, disk, square, star
from skimage.color import rgb2gray,rgba2rgb

# %%
disk = disk(5)
# image1 = rgba2rgb(image1)
# image1 = rgb2gray(image1)

# %%
dilated_image1 = dilation(image1)
io.imshow(dilated_image1, cmap='gray')
io.show()
